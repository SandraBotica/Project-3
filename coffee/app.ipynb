# %% [markdown]
# ### Setup

# %%
import datetime as dt
import numpy as np
import pandas as pd


import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine, func, inspect
import psycopg2

from flask import Flask, jsonify

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/coffee_db')

# %%
# Create an engine that can talk to the database
conn = engine.connect()

# %%
# Base.metadata.create_all(engine)

# %%
# session = Session(bind=engine)

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['coffee_data']

# %% [markdown]
# ### Explore Coffee Database

# %%
data = pd.read_sql("SELECT * FROM coffee_data", conn)

# %%
data.head()
# Out:
#    Id             Country  Year  Import_Volume Export_Volume Growers_Price  \
# 0   0             Austria  1990    1879.717004          None          None
# 1   1             Belgium  1990       0.000000          None          None
# 2   2  Belgium_Luxembourg  1990    2014.954017          None          None
# 3   3            Bulgaria  1990     268.182998          None          None
# 4   4             Croatia  1990       0.000000          None          None
#
#    Retail_Price
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data
# Out:
#         Id                   Country  Year  Import_Volume Export_Volume  \
# 0        0                   Austria  1990    1879.717004          None
# 1        1                   Belgium  1990       0.000000          None
# 2        2        Belgium_Luxembourg  1990    2014.954017          None
# 3        3                  Bulgaria  1990     268.182998          None
# 4        4                   Croatia  1990       0.000000          None
# ...    ...                       ...   ...            ...           ...
# 1045  1045        Russian Federation  2019    5916.632578          None
# 1046  1046               Switzerland  2019    3228.382979          None
# 1047  1047                   Tunisia  2019     508.332000          None
# 1048  1048            United Kingdom  2019    5554.363879          None
# 1049  1049  United States of America  2019   30854.072649          None
#
#      Growers_Price  Retail_Price
# 0             None           NaN
# 1             None           NaN
# 2             None           NaN
# 3             None           NaN
# 4             None           NaN
# ...            ...           ...
# 1045          None      7.116236
# 1046          None      0.000000
# 1047          None           NaN
# 1048          None           NaN
# 1049          None      4.141333
#
# [1050 rows x 7 columns]

# %%
# Get a list of column names and types
columns = inspector.get_columns('coffee_data')
for c in columns:
    print(c['name'], c["type"])
# columns
# Out:
# Id INTEGER
# Country VARCHAR(50)
# Year INTEGER
# Import_Volume DOUBLE_PRECISION
# Export_Volume DOUBLE_PRECISION
# Growers_Price REAL
# Retail_Price REAL

# %%
# Query all records in the Database
data = engine.execute("SELECT * FROM coffee_data")

for record in data:
    print(record)
# Out:
# (0, 'Austria', 1990, 1879.7170038, None, None, None)
# (1, 'Belgium', 1990, 0.0, None, None, None)
# (2, 'Belgium_Luxembourg', 1990, 2014.9540173, None, None, None)
# (3, 'Bulgaria', 1990, 268.1829982, None, None, None)
# (4, 'Croatia', 1990, 0.0, None, None, None)
# (5, 'Cyprus', 1990, 49.853999, None, None, None)
# (6, 'Czechia', 1990, 659.433, None, None, None)
# (7, 'Denmark', 1990, 959.1050037, None, None, None)
# (8, 'Estonia', 1990, 0.0, None, None, None)
# (9, 'Finland', 1990, 1095.1409982, None, None, None)
# (10, 'France', 1990, 6301.2210348, None, None, None)
# (11, 'Germany', 1990, 13670.9460046, None, None, None)
# (12, 'Greece', 1990, 641.9630004, None, None, None)
# (13, 'Hungary', 1990, 573.974, None, None, None)
# (14, 'Ireland', 1990, 129.4770008, None, None, None)
# (15, 'Italy', 1990, 5241.8309999, None, None, None)
# (16, 'Latvia', 1990, 0.0, None, None, None)
# (17, 'Lithuania', 1990, 0.0, None, None, None)
# (18, 'Luxembourg', 1990, 0.0, None, None, None)
# (19, 'Malta', 1990, 20.7139989, None, None, None)
# (20, 'Netherlands', 1990, 3128.1500184, None, None, None)
# (21, 'Poland', 1990, 435.0650014, None, None, None)
# (22, 'Portugal', 1990, 551.5890006, None, None, None)
# (23, 'Romania', 1990, 441.5340034, None, None, None)
# (24, 'Slovakia', 1990, 0.0, None, None, None)
# (25, 'Slovenia', 1990, 0.0, None, None, None)
# (26, 'Spain', 1990, 3053.2510005, None, None, None)
# (27, 'Sweden', 1990, 1766.6740031, None, None, None)
# (28, 'Japan', 1990, 5329.7500039, None, None, None)
# (29, 'Norway', 1990, 742.0400021, None, None, None)
# (30, 'Russian Federation', 1990, 0.0, None, None, None)
# (31, 'Switzerland', 1990, 1170.5080015, None, None, None)
# (32, 'Tunisia', 1990, 100.999998, None, None, None)
# (33, 'United Kingdom', 1990, 2898.2980084, None, None, None)
# (34, 'United States of America', 1990, 21006.7860098, None, None, None)
# (35, 'Austria', 1991, 2058.2710046, None, None, None)
# (36, 'Belgium', 1991, 0.0, None, None, None)
# (37, 'Belgium_Luxembourg', 1991, 1746.2250189, None, None, None)
# (38, 'Bulgaria', 1991, 200.2200014, None, None, None)
# (39, 'Croatia', 1991, 0.0, None, None, None)
# (40, 'Cyprus', 1991, 53.9259999, None, None, None)
# (41, 'Czechia', 1991, 525.274, None, None, None)
# (42, 'Denmark', 1991, 982.7570044, None, None, None)
# (43, 'Estonia', 1991, 0.0, None, None, None)
# (44, 'Finland', 1991, 1033.0669994, None, None, None)
# (45, 'France', 1991, 6552.7090407, None, None, None)
# (46, 'Germany', 1991, 13228.8510044, None, None, None)
# (47, 'Greece', 1991, 407.0270007, None, None, None)
# (48, 'Hungary', 1991, 640.9870026, None, None, None)
# (49, 'Ireland', 1991, 118.2670007, None, None, None)
# (50, 'Italy', 1991, 4630.0230003, None, None, None)
# (51, 'Latvia', 1991, 0.0, None, None, None)
# (52, 'Lithuania', 1991, 0.0, None, None, None)
# (53, 'Luxembourg', 1991, 0.0, None, None, None)
# (54, 'Malta', 1991, 16.0740031, None, None, None)
# (55, 'Netherlands', 1991, 3120.7740193, None, None, None)
# (56, 'Poland', 1991, 249.8710028, None, None, None)
# (57, 'Portugal', 1991, 557.4690006, None, None, None)
# (58, 'Romania', 1991, 335.4500121, None, None, None)
# (59, 'Slovakia', 1991, 0.0, None, None, None)
# (60, 'Slovenia', 1991, 0.0, None, None, None)
# (61, 'Spain', 1991, 2969.5430003, None, None, None)
# (62, 'Sweden', 1991, 1717.0869997, None, None, None)
# (63, 'Japan', 1991, 5510.469001, None, None, None)
# (64, 'Norway', 1991, 761.2149993, None, None, None)
# (65, 'Russian Federation', 1991, 0.0, None, None, None)
# (66, 'Switzerland', 1991, 1130.2920016, None, None, None)
# (67, 'Tunisia', 1991, 90.2010012, None, None, None)
# (68, 'United Kingdom', 1991, 2805.9140049, None, None, None)
# (69, 'United States of America', 1991, 19839.6300126, None, None, None)
# (70, 'Austria', 1992, 2206.416005, None, None, None)
# (71, 'Belgium', 1992, 0.0, None, None, None)
# (72, 'Belgium_Luxembourg', 1992, 1827.8510203, None, None, None)
# (73, 'Bulgaria', 1992, 182.2310123, None, None, None)
# (74, 'Croatia', 1992, 168.1900054, None, None, None)
# (75, 'Cyprus', 1992, 40.8759994, None, None, None)
# (76, 'Czechia', 1992, 474.7310027, None, None, None)
# (77, 'Denmark', 1992, 1061.6230043, None, None, None)
# (78, 'Estonia', 1992, 16.3780004, None, None, None)
# (79, 'Finland', 1992, 1055.3610004, None, None, None)
# (80, 'France', 1992, 6612.0560409, None, None, None)
# (81, 'Germany', 1992, 13788.5540061, None, None, None)
# (82, 'Greece', 1992, 348.9230017, None, None, None)
# (83, 'Hungary', 1992, 522.2479992, None, None, None)
# (84, 'Ireland', 1992, 94.5680001, None, None, None)
# (85, 'Italy', 1992, 4594.7269999, None, None, None)
# (86, 'Latvia', 1992, 20.2589989, None, None, None)
# (87, 'Lithuania', 1992, 1.8630004, None, None, None)
# (88, 'Luxembourg', 1992, 0.0, None, None, None)
# (89, 'Malta', 1992, 17.8580006, None, None, None)
# (90, 'Netherlands', 1992, 3204.9520199, None, None, None)
# (91, 'Poland', 1992, 1787.0570286, None, None, None)
# (92, 'Portugal', 1992, 591.1740014, None, None, None)
# (93, 'Romania', 1992, 603.2080224, None, None, None)
# (94, 'Slovakia', 1992, 0.0, None, None, None)
# (95, 'Slovenia', 1992, 122.8749995, None, None, None)
# (96, 'Spain', 1992, 3414.2900029, None, None, None)
# (97, 'Sweden', 1992, 1771.7250019, None, None, None)
# (98, 'Japan', 1992, 5325.6159975, None, None, None)
# (99, 'Norway', 1992, 739.1450011, None, None, None)
# (100, 'Russian Federation', 1992, 1381.858008, None, None, None)
# (101, 'Switzerland', 1992, 1101.2510016, None, None, None)
# (102, 'Tunisia', 1992, 110.5830012, None, None, None)
# (103, 'United Kingdom', 1992, 3088.172009, None, None, None)
# (104, 'United States of America', 1992, 22939.0330116, None, None, None)
# (105, 'Austria', 1993, 1836.4890021, None, None, None)
# (106, 'Belgium', 1993, 0.0, None, None, None)
# (107, 'Belgium_Luxembourg', 1993, 2063.2600291, None, None, None)
# (108, 'Bulgaria', 1993, 397.4430059, None, None, None)
# (109, 'Croatia', 1993, 162.7740011, None, None, None)
# (110, 'Cyprus', 1993, 77.4120001, None, None, None)
# (111, 'Czechia', 1993, 514.2770051, None, None, None)
# (112, 'Denmark', 1993, 993.9470002, None, None, None)
# (113, 'Estonia', 1993, 51.1479976, None, None, None)
# (114, 'Finland', 1993, 1301.4559992, None, None, None)
# (115, 'France', 1993, 6334.4680437, None, None, None)
# (116, 'Germany', 1993, 14107.0030059, None, None, None)
# (117, 'Greece', 1993, 374.593002, None, None, None)
# (118, 'Hungary', 1993, 668.0559984, None, None, None)
# (119, 'Ireland', 1993, 110.5420007, None, None, None)
# (120, 'Italy', 1993, 5593.7050012, None, None, None)
# (121, 'Latvia', 1993, 59.7739984, None, None, None)
# (122, 'Lithuania', 1993, 9.100001, None, None, None)
# (123, 'Luxembourg', 1993, 0.0, None, None, None)
# (124, 'Malta', 1993, 22.6130018, None, None, None)
# (125, 'Netherlands', 1993, 2803.7290104, None, None, None)
# (126, 'Poland', 1993, 1670.4975109, None, None, None)
# (127, 'Portugal', 1993, 666.4470031, None, None, None)
# (128, 'Romania', 1993, 425.3500156, None, None, None)
# (129, 'Slovakia', 1993, 288.4769937, None, None, None)
# (130, 'Slovenia', 1993, 152.2179984, None, None, None)
# (131, 'Spain', 1993, 2813.0879997, None, None, None)
# (132, 'Sweden', 1993, 1756.6010072, None, None, None)
# (133, 'Japan', 1993, 5691.1200039, None, None, None)
# (134, 'Norway', 1993, 692.8290015, None, None, None)
# (135, 'Russian Federation', 1993, 1794.9460127, None, None, None)
# (136, 'Switzerland', 1993, 1059.8780009, None, None, None)
# (137, 'Tunisia', 1993, 100.6240008, None, None, None)
# (138, 'United Kingdom', 1993, 3196.9810113, None, None, None)
# (139, 'United States of America', 1993, 19328.7210125, None, None, None)
# (140, 'Austria', 1994, 1417.2140039, None, None, None)
# (141, 'Belgium', 1994, 0.0, None, None, None)
# (142, 'Belgium_Luxembourg', 1994, 2262.473036, None, None, None)
# (143, 'Bulgaria', 1994, 462.6680067, None, None, None)
# (144, 'Croatia', 1994, 193.4500023, None, None, None)
# (145, 'Cyprus', 1994, 51.8360006, None, None, None)
# (146, 'Czechia', 1994, 553.7970031, None, None, None)
# (147, 'Denmark', 1994, 1033.1840026, None, None, None)
# (148, 'Estonia', 1994, 83.0979984, None, None, None)
# (149, 'Finland', 1994, 1361.0030016, None, None, None)
# (150, 'France', 1994, 6368.6620423, None, None, None)
# (151, 'Germany', 1994, 13583.2150079, None, None, None)
# (152, 'Greece', 1994, 502.1280018, None, None, None)
# (153, 'Hungary', 1994, 771.2219983, None, None, None)
# (154, 'Ireland', 1994, 130.5400011, None, None, None)
# (155, 'Italy', 1994, 5553.7660032, None, None, None)
# (156, 'Latvia', 1994, 22.5559992, None, None, None)
# (157, 'Lithuania', 1994, 46.726994, None, None, None)
# (158, 'Luxembourg', 1994, 0.0, None, None, None)
# (159, 'Malta', 1994, 13.2119992, None, None, None)
# (160, 'Netherlands', 1994, 2799.8810219, None, None, None)
# (161, 'Poland', 1994, 1842.641218, None, None, None)
# (162, 'Portugal', 1994, 663.8620028, None, None, None)
# (163, 'Romania', 1994, 347.4469961, None, None, None)
# (164, 'Slovakia', 1994, 256.6931383, None, None, None)
# (165, 'Slovenia', 1994, 159.1390023, None, None, None)
# (166, 'Spain', 1994, 3028.4249997, None, None, None)
# (167, 'Sweden', 1994, 1893.2920079, None, None, None)
# (168, 'Japan', 1994, 6217.1510051, None, None, None)
# (169, 'Norway', 1994, 805.6280003, None, None, None)
# (170, 'Russian Federation', 1994, 1725.7300188, None, None, None)
# (171, 'Switzerland', 1994, 1099.4060017, None, None, None)
# (172, 'Tunisia', 1994, 137.2670004, None, None, None)
# (173, 'United Kingdom', 1994, 3465.8600125, None, None, None)
# (174, 'United States of America', 1994, 16171.2450161, None, None, None)
# (175, 'Austria', 1995, 1231.4360012, None, None, None)
# (176, 'Belgium', 1995, 0.0, None, None, None)
# (177, 'Belgium_Luxembourg', 1995, 2401.4980247, None, None, None)
# (178, 'Bulgaria', 1995, 515.418008, None, None, None)
# (179, 'Croatia', 1995, 320.1320059, None, None, None)
# (180, 'Cyprus', 1995, 43.7689997, None, None, None)
# (181, 'Czechia', 1995, 553.1969994, None, None, None)
# (182, 'Denmark', 1995, 877.1590019, None, None, None)
# (183, 'Estonia', 1995, 107.4780016, None, None, None)
# (184, 'Finland', 1995, 769.4989997, None, None, None)
# (185, 'France', 1995, 6213.6800447, None, None, None)
# (186, 'Germany', 1995, 12851.8350055, None, None, None)
# (187, 'Greece', 1995, 522.5950037, None, None, None)
# (188, 'Hungary', 1995, 519.5049966, None, None, None)
# (189, 'Ireland', 1995, 114.6070016, None, None, None)
# (190, 'Italy', 1995, 5387.8610048, None, None, None)
# (191, 'Latvia', 1995, 29.5221127, None, None, None)
# (192, 'Lithuania', 1995, 112.9476799, None, None, None)
# (193, 'Luxembourg', 1995, 0.0, None, None, None)
# (194, 'Malta', 1995, 22.6474855, None, None, None)
# (195, 'Netherlands', 1995, 2910.3660226, None, None, None)
# (196, 'Poland', 1995, 1770.7091091, None, None, None)
# (197, 'Portugal', 1995, 633.1680027, None, None, None)
# (198, 'Romania', 1995, 551.3430059, None, None, None)
# (199, 'Slovakia', 1995, 250.086974, None, None, None)
# (200, 'Slovenia', 1995, 147.6190005, None, None, None)
# (201, 'Spain', 1995, 3145.866003, None, None, None)
# (202, 'Sweden', 1995, 1420.4419989, None, None, None)
# (203, 'Japan', 1995, 5489.087004, None, None, None)
# (204, 'Norway', 1995, 662.0980007, None, None, None)
# (205, 'Russian Federation', 1995, 1728.1440144, None, None, None)
# (206, 'Switzerland', 1995, 1016.829001, None, None, None)
# (207, 'Tunisia', 1995, 136.7830008, None, None, None)
# (208, 'United Kingdom', 1995, 2806.7230152, None, None, None)
# (209, 'United States of America', 1995, 17106.8570142, None, None, None)
# (210, 'Austria', 1996, 1210.4660056, None, None, None)
# (211, 'Belgium', 1996, 0.0, None, None, None)
# (212, 'Belgium_Luxembourg', 1996, 2525.823622, None, None, None)
# (213, 'Bulgaria', 1996, 272.1599948, None, None, None)
# (214, 'Croatia', 1996, 321.8359979, None, None, None)
# (215, 'Cyprus', 1996, 51.5019993, None, None, None)
# (216, 'Czechia', 1996, 525.2980024, None, None, None)
# (217, 'Denmark', 1996, 1005.9992001, None, None, None)
# (218, 'Estonia', 1996, 116.9180065, None, None, None)
# (219, 'Finland', 1996, 992.2736017, None, None, None)
# (220, 'France', 1996, 6659.513448, None, None, None)
# (221, 'Germany', 1996, 13507.1289088, None, None, None)
# (222, 'Greece', 1996, 765.5065046, None, None, None)
# (223, 'Hungary', 1996, 602.9059997, None, None, None)
# (224, 'Ireland', 1996, 98.1580015, None, None, None)
# (225, 'Italy', 1996, 5607.9872065, None, None, None)
# (226, 'Latvia', 1996, 65.7523067, None, None, None)
# (227, 'Lithuania', 1996, 149.5614977, None, None, None)
# (228, 'Luxembourg', 1996, 0.0, None, None, None)
# (229, 'Malta', 1996, 9.2316602, None, None, None)
# (230, 'Netherlands', 1996, 3083.9573207, None, None, None)
# (231, 'Poland', 1996, 1924.0740593, None, None, None)
# (232, 'Portugal', 1996, 742.9592039, None, None, None)
# (233, 'Romania', 1996, 696.558, None, None, None)
# (234, 'Slovakia', 1996, 260.5458129, None, None, None)
# (235, 'Slovenia', 1996, 174.6336196, None, None, None)
# (236, 'Spain', 1996, 3515.2775081, None, None, None)
# (237, 'Sweden', 1996, 1522.3792987, None, None, None)
# (238, 'Japan', 1996, 5994.1130043, None, None, None)
# (239, 'Norway', 1996, 719.8916018, None, None, None)
# (240, 'Russian Federation', 1996, 1127.9720065, None, None, None)
# (241, 'Switzerland', 1996, 1111.6270013, None, None, None)
# (242, 'Tunisia', 1996, 143.6500008, None, None, None)
# (243, 'United Kingdom', 1996, 2903.4531141, None, None, None)
# (244, 'United States of America', 1996, 19444.5331182, None, None, None)
# (245, 'Austria', 1997, 1294.2034055, None, None, None)
# (246, 'Belgium', 1997, 0.0, None, None, None)
# (247, 'Belgium_Luxembourg', 1997, 2544.3793194, None, None, None)
# (248, 'Bulgaria', 1997, 294.1540027, None, None, None)
# (249, 'Croatia', 1997, 385.2970035, None, None, None)
# (250, 'Cyprus', 1997, 41.3409992, None, None, None)
# (251, 'Czechia', 1997, 560.2250029, None, None, None)
# (252, 'Denmark', 1997, 949.0705001, None, None, None)
# (253, 'Estonia', 1997, 141.1149967, None, None, None)
# (254, 'Finland', 1997, 1185.5213024, None, None, None)
# (255, 'France', 1997, 6703.9852508, None, None, None)
# (256, 'Germany', 1997, 13905.1847161, None, None, None)
# (257, 'Greece', 1997, 788.6210034, None, None, None)
# (258, 'Hungary', 1997, 674.9599991, None, None, None)
# (259, 'Ireland', 1997, 106.2836012, None, None, None)
# (260, 'Italy', 1997, 5742.6319091, None, None, None)
# (261, 'Latvia', 1997, 143.6437529, None, None, None)
# (262, 'Lithuania', 1997, 187.1143479, None, None, None)
# (263, 'Luxembourg', 1997, 0.0, None, None, None)
# (264, 'Malta', 1997, 9.4585531, None, None, None)
# (265, 'Netherlands', 1997, 2923.7728279, None, None, None)
# (266, 'Poland', 1997, 2253.0820657, None, None, None)
# (267, 'Portugal', 1997, 727.2904035, None, None, None)
# (268, 'Romania', 1997, 630.977005, None, None, None)
# (269, 'Slovakia', 1997, 252.8846355, None, None, None)
# (270, 'Slovenia', 1997, 170.6471772, None, None, None)
# (271, 'Spain', 1997, 3776.5606067, None, None, None)
# (272, 'Sweden', 1997, 1472.8415002, None, None, None)
# (273, 'Japan', 1997, 5921.4150006, None, None, None)
# (274, 'Norway', 1997, 683.8884018, None, None, None)
# (275, 'Russian Federation', 1997, 2185.2884509, None, None, None)
# (276, 'Switzerland', 1997, 970.7720002, None, None, None)
# (277, 'Tunisia', 1997, 164.6170008, None, None, None)
# (278, 'United Kingdom', 1997, 2929.3380148, None, None, None)
# (279, 'United States of America', 1997, 20342.7458248, None, None, None)
# (280, 'Austria', 1998, 1293.3541061, None, None, None)
# (281, 'Belgium', 1998, 0.0, None, None, None)
# (282, 'Belgium_Luxembourg', 1998, 3579.6779161, None, None, None)
# (283, 'Bulgaria', 1998, 342.1220043, None, None, None)
# (284, 'Croatia', 1998, 339.0510012, None, None, None)
# (285, 'Cyprus', 1998, 49.7789994, None, None, None)
# (286, 'Czechia', 1998, 764.8390017, None, None, None)
# (287, 'Denmark', 1998, 1013.7232012, None, None, None)
# (288, 'Estonia', 1998, 134.6589964, None, None, None)
# (289, 'Finland', 1998, 1167.9353022, None, None, None)
# (290, 'France', 1998, 6576.0226523, None, None, None)
# (291, 'Germany', 1998, 13739.5684148, None, None, None)
# (292, 'Greece', 1998, 704.455603, None, None, None)
# (293, 'Hungary', 1998, 715.5939943, None, None, None)
# (294, 'Ireland', 1998, 101.9779012, None, None, None)
# (295, 'Italy', 1998, 5889.3935096, None, None, None)
# (296, 'Latvia', 1998, 158.9554603, None, None, None)
# (297, 'Lithuania', 1998, 185.1496673, None, None, None)
# (298, 'Luxembourg', 1998, 0.0, None, None, None)
# (299, 'Malta', 1998, 10.1044031, None, None, None)
# (300, 'Netherlands', 1998, 2862.0483243, None, None, None)
# (301, 'Poland', 1998, 2292.9605138, None, None, None)
# (302, 'Portugal', 1998, 761.5868043, None, None, None)
# (303, 'Romania', 1998, 595.3020037, None, None, None)
# (304, 'Slovakia', 1998, 258.9295347, None, None, None)
# (305, 'Slovenia', 1998, 174.3027642, None, None, None)
# (306, 'Spain', 1998, 3717.653605, None, None, None)
# (307, 'Sweden', 1998, 1439.636799, None, None, None)
# (308, 'Japan', 1998, 6026.9650023, None, None, None)
# (309, 'Norway', 1998, 706.8768005, None, None, None)
# (310, 'Russian Federation', 1998, 1731.917618, None, None, None)
# (311, 'Switzerland', 1998, 1111.8350017, None, None, None)
# (312, 'Tunisia', 1998, 147.417, None, None, None)
# (313, 'United Kingdom', 1998, 3142.4080165, None, None, None)
# (314, 'United States of America', 1998, 21030.4011333, None, None, None)
# (315, 'Austria', 1999, 1499.7770114, None, None, None)
# (316, 'Belgium', 1999, 3003.0055122, None, None, None)
# (317, 'Belgium_Luxembourg', 1999, 0.0, None, None, None)
# (318, 'Bulgaria', 1999, 366.9190043, None, None, None)
# (319, 'Croatia', 1999, 352.0830048, None, None, None)
# (320, 'Cyprus', 1999, 55.4585999, None, None, None)
# (321, 'Czechia', 1999, 727.6767881, None, None, None)
# (322, 'Denmark', 1999, 1093.7793024, None, None, None)
# (323, 'Estonia', 1999, 130.9134032, None, None, None)
# (324, 'Finland', 1999, 1209.4849999, None, None, None)
# (325, 'France', 1999, 6675.6656522, None, None, None)
# (326, 'Germany', 1999, 14320.0270212, None, None, None)
# (327, 'Greece', 1999, 732.9623054, None, None, None)
# (328, 'Hungary', 1999, 762.0653045, None, None, None)
# (329, 'Ireland', 1999, 142.0334995, None, None, None)
# (330, 'Italy', 1999, 5943.0875112, None, None, None)
# (331, 'Latvia', 1999, 183.1094766, None, None, None)
# (332, 'Lithuania', 1999, 206.2732062, None, None, None)
# (333, 'Luxembourg', 1999, 145.0452036, None, None, None)
# (334, 'Malta', 1999, 8.9042352, None, None, None)
# (335, 'Netherlands', 1999, 2565.5043218, None, None, None)
# (336, 'Poland', 1999, 2403.6349207, None, None, None)
# (337, 'Portugal', 1999, 816.947305, None, None, None)
# (338, 'Romania', 1999, 511.423008, None, None, None)
# (339, 'Slovakia', 1999, 268.9757881, None, None, None)
# (340, 'Slovenia', 1999, 181.5247271, None, None, None)
# (341, 'Spain', 1999, 3986.023909, None, None, None)
# (342, 'Sweden', 1999, 1455.6766993, None, None, None)
# (343, 'Japan', 1999, 6547.4849994, None, None, None)
# (344, 'Norway', 1999, 789.9776023, None, None, None)
# (345, 'Russian Federation', 1999, 1368.0771672, None, None, None)
# (346, 'Switzerland', 1999, 1138.9260014, None, None, None)
# (347, 'Tunisia', 1999, 185.7474234, None, None, None)
# (348, 'United Kingdom', 1999, 2907.2550112, None, None, None)
# (349, 'United States of America', 1999, 22746.4323379, None, None, None)
# (350, 'Austria', 2000, 1257.2328923, None, None, None)
# (351, 'Belgium', 2000, 3490.6155829, None, None, None)
# (352, 'Belgium_Luxembourg', 2000, 0.0, None, None, None)
# (353, 'Bulgaria', 2000, 280.7270156, None, None, None)
# (354, 'Croatia', 2000, 344.3819963, None, None, None)
# (355, 'Cyprus', 2000, 68.5379972, None, None, None)
# (356, 'Czechia', 2000, 808.9423769, None, None, None)
# (357, 'Denmark', 2000, 1021.7982959, None, None, None)
# (358, 'Estonia', 2000, 105.3046037, None, None, None)
# (359, 'Finland', 2000, 1063.1109996, None, None, None)
# (360, 'France', 2000, 6520.0085794, None, None, None)
# (361, 'Germany', 2000, 13894.5395181, None, None, None)
# (362, 'Greece', 2000, 798.3858564, None, None, None)
# (363, 'Hungary', 2000, 790.2066673, None, None, None)
# (364, 'Ireland', 2000, 154.6881905, None, None, None)
# (365, 'Italy', 2000, 6314.874691, None, None, None)
# (366, 'Latvia', 2000, 181.0516991, None, None, None)
# (367, 'Lithuania', 2000, 212.6624974, None, None, None)
# (368, 'Luxembourg', 2000, 231.7700387, None, None, None)
# (369, 'Malta', 2000, 9.2018914, None, None, None)
# (370, 'Netherlands', 2000, 2965.800776, None, None, None)
# (371, 'Poland', 2000, 2576.3767635, None, None, None)
# (372, 'Portugal', 2000, 811.4328957, None, None, None)
# (373, 'Romania', 2000, 551.5569948, None, None, None)
# (374, 'Slovakia', 2000, 285.9653534, None, None, None)
# (375, 'Slovenia', 2000, 186.7730369, None, None, None)
# (376, 'Spain', 2000, 3768.2017865, None, None, None)
# (377, 'Sweden', 2000, 1344.167892, None, None, None)
# (378, 'Japan', 2000, 6908.0089057, None, None, None)
# (379, 'Norway', 2000, 662.237694, None, None, None)
# (380, 'Russian Federation', 2000, 1890.4529068, None, None, None)
# (381, 'Switzerland', 2000, 1171.4829972, None, None, None)
# (382, 'Tunisia', 2000, 192.4495529, None, None, None)
# (383, 'United Kingdom', 2000, 3012.4008235, None, None, None)
# (384, 'United States of America', 2000, 23766.839355, None, None, None)
# (385, 'Austria', 2001, 1432.4135883, None, None, None)
# (386, 'Belgium', 2001, 3208.6271807, None, None, None)
# (387, 'Belgium_Luxembourg', 2001, 0.0, None, None, None)
# (388, 'Bulgaria', 2001, 354.9049957, None, None, None)
# (389, 'Croatia', 2001, 352.088997, None, None, None)
# (390, 'Cyprus', 2001, 59.0464969, None, None, None)
# (391, 'Czechia', 2001, 899.2526326, None, None, None)
# (392, 'Denmark', 2001, 1102.9635947, None, None, None)
# (393, 'Estonia', 2001, 160.8885019, None, None, None)
# (394, 'Finland', 2001, 1084.0628371, None, None, None)
# (395, 'France', 2001, 6752.7436677, None, None, None)
# (396, 'Germany', 2001, 14753.265918, None, None, None)
# (397, 'Greece', 2001, 867.6429518, None, None, None)
# (398, 'Hungary', 2001, 833.2209675, None, None, None)
# (399, 'Ireland', 2001, 180.1510872, None, None, None)
# (400, 'Italy', 2001, 6541.7312914, None, None, None)
# (401, 'Latvia', 2001, 156.2200386, None, None, None)
# (402, 'Lithuania', 2001, 267.0888845, None, None, None)
# (403, 'Luxembourg', 2001, 209.7060786, None, None, None)
# (404, 'Malta', 2001, 9.3984609, None, None, None)
# (405, 'Netherlands', 2001, 2793.6838743, None, None, None)
# (406, 'Poland', 2001, 2719.3939907, None, None, None)
# (407, 'Portugal', 2001, 843.3808957, None, None, None)
# (408, 'Romania', 2001, 633.171995, None, None, None)
# (409, 'Slovakia', 2001, 317.0047673, None, None, None)
# (410, 'Slovenia', 2001, 194.1829787, None, None, None)
# (411, 'Spain', 2001, 4057.6291818, None, None, None)
# (412, 'Sweden', 2001, 1432.1803929, None, None, None)
# (413, 'Japan', 2001, 6996.1979286, None, None, None)
# (414, 'Norway', 2001, 716.2465941, None, None, None)
# (415, 'Russian Federation', 2001, 3056.870014, None, None, None)
# (416, 'Switzerland', 2001, 1254.5376794, None, None, None)
# (417, 'Tunisia', 2001, 232.9997304, None, None, None)
# (418, 'United Kingdom', 2001, 3061.8273836, None, None, None)
# (419, 'United States of America', 2001, 21415.1411506, None, None, None)
# (420, 'Austria', 2002, 1447.2073888, None, None, None)
# (421, 'Belgium', 2002, 3792.172778, None, None, None)
# (422, 'Belgium_Luxembourg', 2002, 0.0, None, None, None)
# (423, 'Bulgaria', 2002, 343.4319971, None, None, None)
# (424, 'Croatia', 2002, 370.9149955, None, None, None)
# (425, 'Cyprus', 2002, 56.6288971, None, None, None)
# (426, 'Czechia', 2002, 887.8802292, None, None, None)
# (427, 'Denmark', 2002, 1075.8004931, None, None, None)
# (428, 'Estonia', 2002, 119.7034255, None, None, None)
# (429, 'Finland', 2002, 1075.3348981, None, None, None)
# (430, 'France', 2002, 6925.1002666, None, None, None)
# (431, 'Germany', 2002, 15515.5373088, None, None, None)
# (432, 'Greece', 2002, 897.4972501, None, None, None)
# (433, 'Hungary', 2002, 827.5068668, None, None, None)
# (434, 'Ireland', 2002, 176.6015888, None, None, None)
# (435, 'Italy', 2002, 6523.4145888, None, None, None)
# (436, 'Latvia', 2002, 163.8818153, None, None, None)
# (437, 'Lithuania', 2002, 262.8815834, None, None, None)
# (438, 'Luxembourg', 2002, 252.7095085, None, None, None)
# (439, 'Malta', 2002, 9.5642993, None, None, None)
# (440, 'Netherlands', 2002, 2760.0016652, None, None, None)
# (441, 'Poland', 2002, 2643.4962201, None, None, None)
# (442, 'Portugal', 2002, 838.0986973, None, None, None)
# (443, 'Romania', 2002, 738.2578924, None, None, None)
# (444, 'Slovakia', 2002, 300.008801, None, None, None)
# (445, 'Slovenia', 2002, 200.8092839, None, None, None)
# (446, 'Spain', 2002, 4026.115777, None, None, None)
# (447, 'Sweden', 2002, 1463.3086126, None, None, None)
# (448, 'Japan', 2002, 7307.4569309, None, None, None)
# (449, 'Norway', 2002, 697.9739946, None, None, None)
# (450, 'Russian Federation', 2002, 3504.0152149, None, None, None)
# (451, 'Switzerland', 2002, 1216.7448369, None, None, None)
# (452, 'Tunisia', 2002, 235.5659343, None, None, None)
# (453, 'United Kingdom', 2002, 2971.3182038, None, None, None)
# (454, 'United States of America', 2002, 21638.914035, None, None, None)
# (455, 'Austria', 2003, 1336.0595881, None, None, None)
# (456, 'Belgium', 2003, 3817.6140246, None, None, None)
# (457, 'Belgium_Luxembourg', 2003, 0.0, None, None, None)
# (458, 'Bulgaria', 2003, 400.3609976, None, None, None)
# (459, 'Croatia', 2003, 392.5739971, None, None, None)
# (460, 'Cyprus', 2003, 58.7975968, None, None, None)
# (461, 'Czechia', 2003, 974.0662495, None, None, None)
# (462, 'Denmark', 2003, 1001.5821907, None, None, None)
# (463, 'Estonia', 2003, 133.8062641, None, None, None)
# (464, 'Finland', 2003, 1104.7972988, None, None, None)
# (465, 'France', 2003, 6651.823961, None, None, None)
# (466, 'Germany', 2003, 15727.0025165, None, None, None)
# (467, 'Greece', 2003, 997.9742325, None, None, None)
# (468, 'Hungary', 2003, 863.7699913, None, None, None)
# (469, 'Ireland', 2003, 226.7229865, None, None, None)
# (470, 'Italy', 2003, 6929.1902911, None, None, None)
# (471, 'Latvia', 2003, 185.9201579, None, None, None)
# (472, 'Lithuania', 2003, 220.6585037, None, None, None)
# (473, 'Luxembourg', 2003, 288.762576, None, None, None)
# (474, 'Malta', 2003, 10.6619765, None, None, None)
# (475, 'Netherlands', 2003, 3175.5388563, None, None, None)
# (476, 'Poland', 2003, 2664.3447882, None, None, None)
# (477, 'Portugal', 2003, 833.9013876, None, None, None)
# (478, 'Romania', 2003, 755.3403496, None, None, None)
# (479, 'Slovakia', 2003, 302.836118, None, None, None)
# (480, 'Slovenia', 2003, 177.060697, None, None, None)
# (481, 'Spain', 2003, 4135.6172809, None, None, None)
# (482, 'Sweden', 2003, 1434.9268933, None, None, None)
# (483, 'Japan', 2003, 6922.5729317, None, None, None)
# (484, 'Norway', 2003, 690.6792804, None, None, None)
# (485, 'Russian Federation', 2003, 3772.2875457, None, None, None)
# (486, 'Switzerland', 2003, 1321.8698947, None, None, None)
# (487, 'Tunisia', 2003, 123.1478844, None, None, None)
# (488, 'United Kingdom', 2003, 3002.0182301, None, None, None)
# (489, 'United States of America', 2003, 22760.1962049, None, None, None)
# (490, 'Austria', 2004, 1538.1561912, None, None, None)
# (491, 'Belgium', 2004, 3968.3045651, None, None, None)
# (492, 'Belgium_Luxembourg', 2004, 0.0, None, None, None)
# (493, 'Bulgaria', 2004, 366.8488919, None, None, None)
# (494, 'Croatia', 2004, 388.3918396, None, None, None)
# (495, 'Cyprus', 2004, 59.3537956, None, None, None)
# (496, 'Czechia', 2004, 928.8746985, None, None, None)
# (497, 'Denmark', 2004, 1119.4503873, None, None, None)
# (498, 'Estonia', 2004, 175.7325059, None, None, None)
# (499, 'Finland', 2004, 1151.9831992, None, None, None)
# (500, 'France', 2004, 5940.1294572, None, None, None)
# (501, 'Germany', 2004, 17356.0713008, None, None, None)
# (502, 'Greece', 2004, 941.794948, None, None, None)
# (503, 'Hungary', 2004, 977.4179388, None, None, None)
# (504, 'Ireland', 2004, 263.6446817, None, None, None)
# (505, 'Italy', 2004, 7031.9309882, None, None, None)
# (506, 'Latvia', 2004, 187.7697103, None, None, None)
# (507, 'Lithuania', 2004, 256.3850971, None, None, None)
# (508, 'Luxembourg', 2004, 315.8023149, None, None, None)
# (509, 'Malta', 2004, 15.60263, None, None, None)
# (510, 'Netherlands', 2004, 3159.0269523, None, None, None)
# (511, 'Poland', 2004, 2686.8161203, None, None, None)
# (512, 'Portugal', 2004, 838.3407515, None, None, None)
# (513, 'Romania', 2004, 828.316139, None, None, None)
# (514, 'Slovakia', 2004, 298.0047839, None, None, None)
# (515, 'Slovenia', 2004, 196.1821037, None, None, None)
# (516, 'Spain', 2004, 4173.4740747, None, None, None)
# (517, 'Sweden', 2004, 1495.2265968, None, None, None)
# (518, 'Japan', 2004, 7253.9149388, None, None, None)
# (519, 'Norway', 2004, 716.106549, None, None, None)
# (520, 'Russian Federation', 2004, 3205.3914512, None, None, None)
# (521, 'Switzerland', 2004, 1236.2954943, None, None, None)
# (522, 'Tunisia', 2004, 263.9106944, None, None, None)
# (523, 'United Kingdom', 2004, 3328.6803854, None, None, None)
# (524, 'United States of America', 2004, 23183.9535285, None, None, None)
# (525, 'Austria', 2005, 1576.5789304, None, None, None)
# (526, 'Belgium', 2005, 4063.2250758, None, None, None)
# (527, 'Belgium_Luxembourg', 2005, 0.0, None, None, None)
# (528, 'Bulgaria', 2005, 440.5141695, None, None, None)
# (529, 'Croatia', 2005, 391.5995398, None, None, None)
# (530, 'Cyprus', 2005, 80.0981044, None, None, None)
# (531, 'Czechia', 2005, 1063.4138261, None, None, None)
# (532, 'Denmark', 2005, 993.3597532, None, None, None)
# (533, 'Estonia', 2005, 221.1360714, None, None, None)
# (534, 'Finland', 2005, 1156.4411936, None, None, None)
# (535, 'France', 2005, 5714.0085755, None, None, None)
# (536, 'Germany', 2005, 16716.0487482, None, None, None)
# (537, 'Greece', 2005, 930.5928816, None, None, None)
# (538, 'Hungary', 2005, 851.7228942, None, None, None)
# (539, 'Ireland', 2005, 251.2797772, None, None, None)
# (540, 'Italy', 2005, 7268.6127576, None, None, None)
# (541, 'Latvia', 2005, 191.0852159, None, None, None)
# (542, 'Lithuania', 2005, 283.766579, None, None, None)
# (543, 'Luxembourg', 2005, 330.7952253, None, None, None)
# (544, 'Malta', 2005, 16.3020906, None, None, None)
# (545, 'Netherlands', 2005, 2988.0150659, None, None, None)
# (546, 'Poland', 2005, 2791.5043949, None, None, None)
# (547, 'Portugal', 2005, 831.216247, None, None, None)
# (548, 'Romania', 2005, 874.3634689, None, None, None)
# (549, 'Slovakia', 2005, 307.6241833, None, None, None)
# (550, 'Slovenia', 2005, 190.8816912, None, None, None)
# (551, 'Spain', 2005, 4356.0820322, None, None, None)
# (552, 'Sweden', 2005, 1693.0028646, None, None, None)
# (553, 'Japan', 2005, 7407.8339939, None, None, None)
# (554, 'Norway', 2005, 753.0594269, None, None, None)
# (555, 'Russian Federation', 2005, 3335.8034788, None, None, None)
# (556, 'Switzerland', 2005, 1641.0493279, None, None, None)
# (557, 'Tunisia', 2005, 189.9735264, None, None, None)
# (558, 'United Kingdom', 2005, 3433.3041887, None, None, None)
# (559, 'United States of America', 2005, 23041.5158603, None, None, None)
# (560, 'Austria', 2006, 1600.652025, None, None, None)
# (561, 'Belgium', 2006, 4604.6839771, None, None, None)
# (562, 'Belgium_Luxembourg', 2006, 0.0, None, None, None)
# (563, 'Bulgaria', 2006, 434.5516861, None, None, None)
# (564, 'Croatia', 2006, 404.1215639, None, None, None)
# (565, 'Cyprus', 2006, 73.8042354, None, None, None)
# (566, 'Czechia', 2006, 940.4783432, None, None, None)
# (567, 'Denmark', 2006, 1004.1628306, None, None, None)
# (568, 'Estonia', 2006, 254.4241989, None, None, None)
# (569, 'Finland', 2006, 1167.9794743, None, None, None)
# (570, 'France', 2006, 6190.5316213, None, None, None)
# (571, 'Germany', 2006, 18542.8432739, None, None, None)
# (572, 'Greece', 2006, 897.1270418, None, None, None)
# (573, 'Hungary', 2006, 900.5479963, None, None, None)
# (574, 'Ireland', 2006, 252.243941, None, None, None)
# (575, 'Italy', 2006, 7547.5259722, None, None, None)
# (576, 'Latvia', 2006, 220.5149361, None, None, None)
# (577, 'Lithuania', 2006, 316.6480403, None, None, None)
# (578, 'Luxembourg', 2006, 335.5344162, None, None, None)
# (579, 'Malta', 2006, 28.8739154, None, None, None)
# (580, 'Netherlands', 2006, 3292.8052493, None, None, None)
# (581, 'Poland', 2006, 2653.6604533, None, None, None)
# (582, 'Portugal', 2006, 861.681076, None, None, None)
# (583, 'Romania', 2006, 854.2594041, None, None, None)
# (584, 'Slovakia', 2006, 347.1733412, None, None, None)
# (585, 'Slovenia', 2006, 186.6595548, None, None, None)
# (586, 'Spain', 2006, 4538.3597705, None, None, None)
# (587, 'Sweden', 2006, 1820.4821677, None, None, None)
# (588, 'Japan', 2006, 7631.5520665, None, None, None)
# (589, 'Norway', 2006, 731.1092265, None, None, None)
# (590, 'Russian Federation', 2006, 3465.1402007, None, None, None)
# (591, 'Switzerland', 2006, 1502.6202816, None, None, None)
# (592, 'Tunisia', 2006, 209.4635923, None, None, None)
# (593, 'United Kingdom', 2006, 4045.7886348, None, None, None)
# (594, 'United States of America', 2006, 23708.762276, None, None, None)
# (595, 'Austria', 2007, 1968.1126993, None, None, None)
# (596, 'Belgium', 2007, 4013.653412, None, None, None)
# (597, 'Belgium_Luxembourg', 2007, 0.0, None, None, None)
# (598, 'Bulgaria', 2007, 393.3613084, None, None, None)
# (599, 'Croatia', 2007, 413.7646766, None, None, None)
# (600, 'Cyprus', 2007, 71.4217923, None, None, None)
# (601, 'Czechia', 2007, 1037.0786611, None, None, None)
# (602, 'Denmark', 2007, 995.1983116, None, None, None)
# (603, 'Estonia', 2007, 277.1065846, None, None, None)
# (604, 'Finland', 2007, 1207.0293039, None, None, None)
# (605, 'France', 2007, 6420.2704654, None, None, None)
# (606, 'Germany', 2007, 19564.0533021, None, None, None)
# (607, 'Greece', 2007, 1080.8867376, None, None, None)
# (608, 'Hungary', 2007, 893.5887951, None, None, None)
# (609, 'Ireland', 2007, 266.460501, None, None, None)
# (610, 'Italy', 2007, 8028.4634618, None, None, None)
# (611, 'Latvia', 2007, 150.6349888, None, None, None)
# (612, 'Lithuania', 2007, 335.5472118, None, None, None)
# (613, 'Luxembourg', 2007, 359.567489, None, None, None)
# (614, 'Malta', 2007, 15.9168353, None, None, None)
# (615, 'Netherlands', 2007, 3531.0194162, None, None, None)
# (616, 'Poland', 2007, 2263.6697769, None, None, None)
# (617, 'Portugal', 2007, 911.2966055, None, None, None)
# (618, 'Romania', 2007, 839.7552358, None, None, None)
# (619, 'Slovakia', 2007, 508.2651246, None, None, None)
# (620, 'Slovenia', 2007, 204.5546386, None, None, None)
# (621, 'Spain', 2007, 4874.7485723, None, None, None)
# (622, 'Sweden', 2007, 1769.6684756, None, None, None)
# (623, 'Japan', 2007, 7086.223924, None, None, None)
# (624, 'Norway', 2007, 779.8934161, None, None, None)
# (625, 'Russian Federation', 2007, 4317.8989966, None, None, None)
# (626, 'Switzerland', 2007, 1823.1084053, None, None, None)
# (627, 'Tunisia', 2007, 253.4181323, None, None, None)
# (628, 'United Kingdom', 2007, 3780.5481201, None, None, None)
# (629, 'United States of America', 2007, 24219.2816408, None, None, None)
# (630, 'Austria', 2008, 1901.0666958, None, None, None)
# (631, 'Belgium', 2008, 6792.086621, None, None, None)
# (632, 'Belgium_Luxembourg', 2008, 0.0, None, None, None)
# (633, 'Bulgaria', 2008, 517.2056848, None, None, None)
# (634, 'Croatia', 2008, 405.3261764, None, None, None)
# (635, 'Cyprus', 2008, 77.5144181, None, None, None)
# (636, 'Czechia', 2008, 1037.3267569, None, None, None)
# (637, 'Denmark', 2008, 900.3654349, None, None, None)
# (638, 'Estonia', 2008, 334.3833741, None, None, None)
# (639, 'Finland', 2008, 1284.7945526, None, None, None)
# (640, 'France', 2008, 6251.7391243, None, None, None)
# (641, 'Germany', 2008, 19876.2373203, None, None, None)
# (642, 'Greece', 2008, 1056.0362867, None, None, None)
# (643, 'Hungary', 2008, 810.7674443, None, None, None)
# (644, 'Ireland', 2008, 127.4225179, None, None, None)
# (645, 'Italy', 2008, 8172.1041052, None, None, None)
# (646, 'Latvia', 2008, 154.2490378, None, None, None)
# (647, 'Lithuania', 2008, 390.4983777, None, None, None)
# (648, 'Luxembourg', 2008, 351.4133229, None, None, None)
# (649, 'Malta', 2008, 23.0189032, None, None, None)
# (650, 'Netherlands', 2008, 2304.4434678, None, None, None)
# (651, 'Poland', 2008, 2460.3447509, None, None, None)
# (652, 'Portugal', 2008, 885.0714718, None, None, None)
# (653, 'Romania', 2008, 826.1034899, None, None, None)
# (654, 'Slovakia', 2008, 610.5763029, None, None, None)
# (655, 'Slovenia', 2008, 205.0569858, None, None, None)
# (656, 'Spain', 2008, 4863.7677611, None, None, None)
# (657, 'Sweden', 2008, 1804.1263654, None, None, None)
# (658, 'Japan', 2008, 7060.0324058, None, None, None)
# (659, 'Norway', 2008, 721.8867359, None, None, None)
# (660, 'Russian Federation', 2008, 4053.18973, None, None, None)
# (661, 'Switzerland', 2008, 1977.6881329, None, None, None)
# (662, 'Tunisia', 2008, 317.612091, None, None, None)
# (663, 'United Kingdom', 2008, 3967.4576895, None, None, None)
# (664, 'United States of America', 2008, 24277.0043402, None, None, None)
# (665, 'Austria', 2009, 1309.234032, None, None, None)
# (666, 'Belgium', 2009, 5915.5005882, None, None, None)
# (667, 'Belgium_Luxembourg', 2009, 0.0, None, None, None)
# (668, 'Bulgaria', 2009, 522.9957876, None, None, None)
# (669, 'Croatia', 2009, 394.0485164, None, None, None)
# (670, 'Cyprus', 2009, 71.7398673, None, None, None)
# (671, 'Czechia', 2009, 930.025889, None, None, None)
# (672, 'Denmark', 2009, 859.8465934, None, None, None)
# (673, 'Estonia', 2009, 357.2725337, None, None, None)
# (674, 'Finland', 2009, 1243.2638329, None, None, None)
# (675, 'France', 2009, 6669.7282046, None, None, None)
# (676, 'Germany', 2009, 19415.6654721, None, None, None)
# (677, 'Greece', 2009, 1046.0177255, None, None, None)
# (678, 'Hungary', 2009, 703.9380789, None, None, None)
# (679, 'Ireland', 2009, 142.0139971, None, None, None)
# (680, 'Italy', 2009, 8078.1685675, None, None, None)
# (681, 'Latvia', 2009, 131.9782402, None, None, None)
# (682, 'Lithuania', 2009, 410.9345791, None, None, None)
# (683, 'Luxembourg', 2009, 329.9509344, None, None, None)
# (684, 'Malta', 2009, 14.217842, None, None, None)
# (685, 'Netherlands', 2009, 2502.132848, None, None, None)
# (686, 'Poland', 2009, 3161.536735, None, None, None)
# (687, 'Portugal', 2009, 886.7256047, None, None, None)
# (688, 'Romania', 2009, 811.4623014, None, None, None)
# (689, 'Slovakia', 2009, 458.3967628, None, None, None)
# (690, 'Slovenia', 2009, 210.2408723, None, None, None)
# (691, 'Spain', 2009, 4811.2844156, None, None, None)
# (692, 'Sweden', 2009, 1658.6543175, None, None, None)
# (693, 'Japan', 2009, 7089.7017574, None, None, None)
# (694, 'Norway', 2009, 724.4068942, None, None, None)
# (695, 'Russian Federation', 2009, 3553.1612896, None, None, None)
# (696, 'Switzerland', 2009, 2101.0004279, None, None, None)
# (697, 'Tunisia', 2009, 288.7988684, None, None, None)
# (698, 'United Kingdom', 2009, 4130.9076273, None, None, None)
# (699, 'United States of America', 2009, 23578.0649485, None, None, None)
# (700, 'Austria', 2010, 1369.2002988, None, None, None)
# (701, 'Belgium', 2010, 5923.7299927, None, None, None)
# (702, 'Belgium_Luxembourg', 2010, 0.0, None, None, None)
# (703, 'Bulgaria', 2010, 528.3720815, None, None, None)
# (704, 'Croatia', 2010, 393.825469, None, None, None)
# (705, 'Cyprus', 2010, 76.7284479, None, None, None)
# (706, 'Czechia', 2010, 950.7219282, None, None, None)
# (707, 'Denmark', 2010, 1014.6408946, None, None, None)
# (708, 'Estonia', 2010, 262.8701871, None, None, None)
# (709, 'Finland', 2010, 1273.7434428, None, None, None)
# (710, 'France', 2010, 6717.2418889, None, None, None)
# (711, 'Germany', 2010, 20602.955791, None, None, None)
# (712, 'Greece', 2010, 1061.3275425, None, None, None)
# (713, 'Hungary', 2010, 726.8896947, None, None, None)
# (714, 'Ireland', 2010, 164.7366941, None, None, None)
# (715, 'Italy', 2010, 8235.9621708, None, None, None)
# (716, 'Latvia', 2010, 137.6645663, None, None, None)
# (717, 'Lithuania', 2010, 376.0536971, None, None, None)
# (718, 'Luxembourg', 2010, 348.8748621, None, None, None)
# (719, 'Malta', 2010, 12.176685, None, None, None)
# (720, 'Netherlands', 2010, 2582.6607653, None, None, None)
# (721, 'Poland', 2010, 3278.9140979, None, None, None)
# (722, 'Portugal', 2010, 1010.4420398, None, None, None)
# (723, 'Romania', 2010, 838.8552395, None, None, None)
# (724, 'Slovakia', 2010, 654.8483112, None, None, None)
# (725, 'Slovenia', 2010, 217.5864811, None, None, None)
# (726, 'Spain', 2010, 5034.4030716, None, None, None)
# (727, 'Sweden', 2010, 1726.6798355, None, None, None)
# (728, 'Japan', 2010, 7407.0803259, None, None, None)
# (729, 'Norway', 2010, 759.353092, None, None, None)
# (730, 'Russian Federation', 2010, 4155.2569235, None, None, None)
# (731, 'Switzerland', 2010, 2317.6060297, None, None, None)
# (732, 'Tunisia', 2010, 304.0903304, None, None, None)
# (733, 'United Kingdom', 2010, 4301.908141, None, None, None)
# (734, 'United States of America', 2010, 24378.013044, None, None, None)
# (735, 'Austria', 2011, 1452.4929051, None, None, None)
# (736, 'Belgium', 2011, 5828.442382, None, None, None)
# (737, 'Belgium_Luxembourg', 2011, 0.0, None, None, None)
# (738, 'Bulgaria', 2011, 481.5102089, None, None, None)
# (739, 'Croatia', 2011, 390.8739587, None, None, None)
# (740, 'Cyprus', 2011, 82.0787537, None, None, None)
# (741, 'Czechia', 2011, 952.3665949, None, None, None)
# (742, 'Denmark', 2011, 908.8697406, None, None, None)
# (743, 'Estonia', 2011, 166.8557318, None, None, None)
# (744, 'Finland', 2011, 1286.5150648, None, None, None)
# (745, 'France', 2011, 6991.820108, None, None, None)
# (746, 'Germany', 2011, 20926.4045801, None, None, None)
# (747, 'Greece', 2011, 1154.5258226, None, None, None)
# (748, 'Hungary', 2011, 639.6242626, None, None, None)
# (749, 'Ireland', 2011, 210.4429221, None, None, None)
# (750, 'Italy', 2011, 8355.3425742, None, None, None)
# (751, 'Latvia', 2011, 141.2808683, None, None, None)
# (752, 'Lithuania', 2011, 288.8753765, None, None, None)
# (753, 'Luxembourg', 2011, 325.5287339, None, None, None)
# (754, 'Malta', 2011, 16.9565037, None, None, None)
# (755, 'Netherlands', 2011, 2678.3343271, None, None, None)
# (756, 'Poland', 2011, 3403.8193109, None, None, None)
# (757, 'Portugal', 2011, 1057.7339554, None, None, None)
# (758, 'Romania', 2011, 844.1848875, None, None, None)
# (759, 'Slovakia', 2011, 777.2147213, None, None, None)
# (760, 'Slovenia', 2011, 222.9886267, None, None, None)
# (761, 'Spain', 2011, 4820.9077122, None, None, None)
# (762, 'Sweden', 2011, 1646.7261696, None, None, None)
# (763, 'Japan', 2011, 7543.8558918, None, None, None)
# (764, 'Norway', 2011, 794.9170203, None, None, None)
# (765, 'Russian Federation', 2011, 4217.6827922, None, None, None)
# (766, 'Switzerland', 2011, 2497.9141443, None, None, None)
# (767, 'Tunisia', 2011, 428.7820528, None, None, None)
# (768, 'United Kingdom', 2011, 4183.2298796, None, None, None)
# (769, 'United States of America', 2011, 26093.3947573, None, None, None)
# (770, 'Austria', 2012, 1558.6093658, None, None, None)
# (771, 'Belgium', 2012, 5668.2318442, None, None, None)
# (772, 'Belgium_Luxembourg', 2012, 0.0, None, None, None)
# (773, 'Bulgaria', 2012, 559.8250658, None, None, None)
# (774, 'Croatia', 2012, 384.4903604, None, None, None)
# (775, 'Cyprus', 2012, 83.8774691, None, None, None)
# (776, 'Czechia', 2012, 1126.6229015, None, None, None)
# (777, 'Denmark', 2012, 913.0989936, None, None, None)
# (778, 'Estonia', 2012, 157.2347896, None, None, None)
# (779, 'Finland', 2012, 1237.8330405, None, None, None)
# (780, 'France', 2012, 6841.1355565, None, None, None)
# (781, 'Germany', 2012, 21816.2120076, None, None, None)
# (782, 'Greece', 2012, 1243.663331, None, None, None)
# (783, 'Hungary', 2012, 747.9277087, None, None, None)
# (784, 'Ireland', 2012, 252.0045146, None, None, None)
# (785, 'Italy', 2012, 8690.8697162, None, None, None)
# (786, 'Latvia', 2012, 156.9856449, None, None, None)
# (787, 'Lithuania', 2012, 336.6761214, None, None, None)
# (788, 'Luxembourg', 2012, 322.7530169, None, None, None)
# (789, 'Malta', 2012, 21.2989369, None, None, None)
# (790, 'Netherlands', 2012, 2729.7607877, None, None, None)
# (791, 'Poland', 2012, 3542.745725, None, None, None)
# (792, 'Portugal', 2012, 1075.842247, None, None, None)
# (793, 'Romania', 2012, 902.8725244, None, None, None)
# (794, 'Slovakia', 2012, 771.6301858, None, None, None)
# (795, 'Slovenia', 2012, 220.8954987, None, None, None)
# (796, 'Spain', 2012, 5094.0200696, None, None, None)
# (797, 'Sweden', 2012, 1679.734595, None, None, None)
# (798, 'Japan', 2012, 7024.8599398, None, None, None)
# (799, 'Norway', 2012, 735.4431612, None, None, None)
# (800, 'Russian Federation', 2012, 4174.7446231, None, None, None)
# (801, 'Switzerland', 2012, 2477.957193, None, None, None)
# (802, 'Tunisia', 2012, 438.9237008, None, None, None)
# (803, 'United Kingdom', 2012, 4126.0536807, None, None, None)
# (804, 'United States of America', 2012, 26056.1625744, None, None, None)
# (805, 'Austria', 2013, 1554.9269506, None, None, None)
# (806, 'Belgium', 2013, 5502.1436397, None, None, None)
# (807, 'Belgium_Luxembourg', 2013, 0.0, None, None, None)
# (808, 'Bulgaria', 2013, 609.4866685, None, None, None)
# (809, 'Croatia', 2013, 412.8494215, None, None, None)
# (810, 'Cyprus', 2013, 93.7661831, None, None, None)
# (811, 'Czechia', 2013, 1183.8822421, None, None, None)
# (812, 'Denmark', 2013, 921.1789153, None, None, None)
# (813, 'Estonia', 2013, 156.214012, None, None, None)
# (814, 'Finland', 2013, 1275.4679654, None, None, None)
# (815, 'France', 2013, 6713.1048553, None, None, None)
# (816, 'Germany', 2013, 21174.3069122, None, None, None)
# (817, 'Greece', 2013, 1269.0939563, None, None, None)
# (818, 'Hungary', 2013, 557.3970482, None, None, None)
# (819, 'Ireland', 2013, 232.744596, None, None, None)
# (820, 'Italy', 2013, 8822.5448997, None, None, None)
# (821, 'Latvia', 2013, 161.2889113, None, None, None)
# (822, 'Lithuania', 2013, 362.1864369, None, None, None)
# (823, 'Luxembourg', 2013, 378.1732517, None, None, None)
# (824, 'Malta', 2013, 21.8973088, None, None, None)
# (825, 'Netherlands', 2013, 3406.7949082, None, None, None)
# (826, 'Poland', 2013, 3284.3826312, None, None, None)
# (827, 'Portugal', 2013, 1062.6816116, None, None, None)
# (828, 'Romania', 2013, 971.4770729, None, None, None)
# (829, 'Slovakia', 2013, 798.425339, None, None, None)
# (830, 'Slovenia', 2013, 257.9152003, None, None, None)
# (831, 'Spain', 2013, 5136.9432641, None, None, None)
# (832, 'Sweden', 2013, 1709.3890993, None, None, None)
# (833, 'Japan', 2013, 8381.262867, None, None, None)
# (834, 'Norway', 2013, 781.4842885, None, None, None)
# (835, 'Russian Federation', 2013, 4410.1934609, None, None, None)
# (836, 'Switzerland', 2013, 2666.7506995, None, None, None)
# (837, 'Tunisia', 2013, 438.9672683, None, None, None)
# (838, 'United Kingdom', 2013, 4206.0909254, None, None, None)
# (839, 'United States of America', 2013, 27015.5401601, None, None, None)
# (840, 'Austria', 2014, 1525.0810799, None, None, 8.63)
# (841, 'Belgium', 2014, 5211.7492738, None, None, 0.0)
# (842, 'Belgium_Luxembourg', 2014, 0.0, None, None, None)
# (843, 'Bulgaria', 2014, 620.7089657, None, None, 3.75)
# (844, 'Croatia', 2014, 419.6735498, None, None, None)
# (845, 'Cyprus', 2014, 94.3881005, None, None, 6.48)
# (846, 'Czechia', 2014, 1822.6907791, None, None, 6.61)
# (847, 'Denmark', 2014, 853.4238792, None, None, 6.43)
# (848, 'Estonia', 2014, 130.8537127, None, None, None)
# (849, 'Finland', 2014, 1213.0553801, None, None, 4.31)
# (850, 'France', 2014, 7112.3061337, None, None, 3.77)
# (851, 'Germany', 2014, 22077.6936639, None, None, 5.72)
# (852, 'Greece', 2014, 1233.6054064, None, None, None)
# (853, 'Hungary', 2014, 833.4492506, None, None, 4.86)
# (854, 'Ireland', 2014, 291.8597102, None, None, None)
# (855, 'Italy', 2014, 9349.8224226, None, None, 8.85)
# (856, 'Latvia', 2014, 213.3881125, None, None, 6.89)
# (857, 'Lithuania', 2014, 396.4783766, None, None, 6.55)
# (858, 'Luxembourg', 2014, 413.0426555, None, None, 7.92)
# (859, 'Malta', 2014, 24.6340662, None, None, 14.93)
# (860, 'Netherlands', 2014, 4016.0222823, None, None, 5.71)
# (861, 'Poland', 2014, 3229.2077791, None, None, 3.85)
# (862, 'Portugal', 2014, 1059.7494969, None, None, 5.73)
# (863, 'Romania', 2014, 958.4832475, None, None, None)
# (864, 'Slovakia', 2014, 918.8925842, None, None, 6.67)
# (865, 'Slovenia', 2014, 268.9250769, None, None, 4.62)
# (866, 'Spain', 2014, 5405.5576389, None, None, 4.44)
# (867, 'Sweden', 2014, 2198.4630628, None, None, 4.11)
# (868, 'Japan', 2014, 7656.9829903, None, None, 5.68)
# (869, 'Norway', 2014, 743.1754294, None, None, 7.5)
# (870, 'Russian Federation', 2014, 4746.9496269, None, None, 7.65)
# (871, 'Switzerland', 2014, 2643.1063138, None, None, 0.0)
# (872, 'Tunisia', 2014, 460.0278903, None, None, None)
# (873, 'United Kingdom', 2014, 4318.695591, None, None, None)
# (874, 'United States of America', 2014, 27565.4976238, None, None, 4.99)
# (875, 'Austria', 2015, 1513.3902855, None, None, 7.44)
# (876, 'Belgium', 2015, 5533.5142058, None, None, 0.0)
# (877, 'Belgium_Luxembourg', 2015, 0.0, None, None, None)
# (878, 'Bulgaria', 2015, 681.7565892, None, None, 3.45)
# (879, 'Croatia', 2015, 437.201445, None, None, None)
# (880, 'Cyprus', 2015, 89.3048755, None, None, 5.3)
# (881, 'Czechia', 2015, 2067.8385692, None, None, 5.75)
# (882, 'Denmark', 2015, 840.7776365, None, None, 5.85)
# (883, 'Estonia', 2015, 126.2006378, None, None, None)
# (884, 'Finland', 2015, 1320.8022792, None, None, 3.9)
# (885, 'France', 2015, 6808.5666402, None, None, 3.11)
# (886, 'Germany', 2015, 21316.2117179, None, None, 5.18)
# (887, 'Greece', 2015, 1209.9645243, None, None, None)
# (888, 'Hungary', 2015, 714.2093939, None, None, 4.16)
# (889, 'Ireland', 2015, 356.5710867, None, None, None)
# (890, 'Italy', 2015, 9328.1932718, None, None, 7.48)
# (891, 'Latvia', 2015, 201.5931207, None, None, 6.57)
# (892, 'Lithuania', 2015, 427.7571993, None, None, 6.06)
# (893, 'Luxembourg', 2015, 376.2258486, None, None, 6.97)
# (894, 'Malta', 2015, 16.3133795, None, None, 12.8)
# (895, 'Netherlands', 2015, 4176.2358257, None, None, 5.38)
# (896, 'Poland', 2015, 3665.6120676, None, None, 3.28)
# (897, 'Portugal', 2015, 1043.8569623, None, None, 4.99)
# (898, 'Romania', 2015, 1011.6432213, None, None, None)
# (899, 'Slovakia', 2015, 910.3847558, None, None, 5.6)
# (900, 'Slovenia', 2015, 271.7857211, None, None, 4.03)
# (901, 'Spain', 2015, 5428.5651704, None, None, 3.82)
# (902, 'Sweden', 2015, 2120.5513369, None, None, 3.82)
# (903, 'Japan', 2015, 8063.3980222, None, None, 5.6)
# (904, 'Norway', 2015, 799.7403054, None, None, 5.81)
# (905, 'Russian Federation', 2015, 4710.0381459, None, None, 6.43)
# (906, 'Switzerland', 2015, 2747.8585079, None, None, 0.0)
# (907, 'Tunisia', 2015, 458.7069518, None, None, None)
# (908, 'United Kingdom', 2015, 4895.4072875, None, None, None)
# (909, 'United States of America', 2015, 27707.6637017, None, None, 4.72)
# (910, 'Austria', 2016, 1494.9385599, None, None, 5.64)
# (911, 'Belgium', 2016, 6052.1701635, None, None, 0.0)
# (912, 'Belgium_Luxembourg', 2016, 0.0, None, None, None)
# (913, 'Bulgaria', 2016, 779.1600127, None, None, 3.79)
# (914, 'Croatia', 2016, 478.6666582, None, None, None)
# (915, 'Cyprus', 2016, 93.1533074, None, None, 5.3)
# (916, 'Czechia', 2016, 1779.3512446, None, None, 6.14)
# (917, 'Denmark', 2016, 905.7896194, None, None, 4.94)
# (918, 'Estonia', 2016, 134.8026375, None, None, None)
# (919, 'Finland', 2016, 1388.9662796, None, None, 3.67)
# (920, 'France', 2016, 6737.7827096, None, None, 3.26)
# (921, 'Germany', 2016, 22368.3907812, None, None, 5.05)
# (922, 'Greece', 2016, 1583.737836, None, None, None)
# (923, 'Hungary', 2016, 725.4383182, None, None, 4.31)
# (924, 'Ireland', 2016, 402.6304702, None, None, None)
# (925, 'Italy', 2016, 10224.1888254, None, None, 7.45)
# (926, 'Latvia', 2016, 231.2908269, None, None, 6.46)
# (927, 'Lithuania', 2016, 499.2703906, None, None, 6.08)
# (928, 'Luxembourg', 2016, 394.3287395, None, None, 7.24)
# (929, 'Malta', 2016, 18.5323229, None, None, 13.33)
# (930, 'Netherlands', 2016, 4781.4501766, None, None, 4.77)
# (931, 'Poland', 2016, 3827.1689541, None, None, 3.17)
# (932, 'Portugal', 2016, 1128.4814182, None, None, 4.93)
# (933, 'Romania', 2016, 1133.6988825, None, None, None)
# (934, 'Slovakia', 2016, 906.1834351, None, None, 5.74)
# (935, 'Slovenia', 2016, 322.870291, None, None, 3.96)
# (936, 'Spain', 2016, 5660.1469376, None, None, 3.73)
# (937, 'Sweden', 2016, 2349.8694959, None, None, 3.48)
# (938, 'Japan', 2016, 8026.1544847, None, None, 6.21)
# (939, 'Norway', 2016, 799.1477071, None, None, 5.56)
# (940, 'Russian Federation', 2016, 5232.8811694, None, None, 6.65)
# (941, 'Switzerland', 2016, 2816.0260863, None, None, 0.0)
# (942, 'Tunisia', 2016, 465.5530213, None, None, None)
# (943, 'United Kingdom', 2016, 5052.2934594, None, None, None)
# (944, 'United States of America', 2016, 28837.8378373, None, None, 4.39)
# (945, 'Austria', 2017, 1459.9115324, None, None, 6.22)
# (946, 'Belgium', 2017, 5677.3791389, None, None, 0.0)
# (947, 'Belgium_Luxembourg', 2017, 0.0, None, None, None)
# (948, 'Bulgaria', 2017, 706.8825173, None, None, 4.64)
# (949, 'Croatia', 2017, 439.0744122, None, None, None)
# (950, 'Cyprus', 2017, 99.9338742, None, None, 5.5)
# (951, 'Czechia', 2017, 1506.9672190000001, None, None, 6.58)
# (952, 'Denmark', 2017, 852.1933331, None, None, 5.03)
# (953, 'Estonia', 2017, 133.1481382, None, None, None)
# (954, 'Finland', 2017, 1360.0237362, None, None, 4.1)
# (955, 'France', 2017, 6966.5146634, None, None, 3.4)
# (956, 'Germany', 2017, 21764.7838616, None, None, 5.34)
# (957, 'Greece', 2017, 867.1193788, None, None, None)
# (958, 'Hungary', 2017, 721.5608351, None, None, 4.83)
# (959, 'Ireland', 2017, 426.9155363, None, None, None)
# (960, 'Italy', 2017, 10020.2733155, None, None, 7.67)
# (961, 'Latvia', 2017, 228.9203402, None, None, 6.69)
# (962, 'Lithuania', 2017, 432.4523425, None, None, 6.29)
# (963, 'Luxembourg', 2017, 379.9285554, None, None, 7.56)
# (964, 'Malta', 2017, 16.754442, None, None, 14.05)
# (965, 'Netherlands', 2017, 5067.7405401, None, None, 4.83)
# (966, 'Poland', 2017, 3999.3185993, None, None, 3.45)
# (967, 'Portugal', 2017, 1093.954625, None, None, 5.04)
# (968, 'Romania', 2017, 1154.5733407, None, None, None)
# (969, 'Slovakia', 2017, 723.0503587, None, None, 6.0)
# (970, 'Slovenia', 2017, 401.4388073, None, None, 4.2)
# (971, 'Spain', 2017, 5414.2292529, None, None, 3.84)
# (972, 'Sweden', 2017, 2306.3321627, None, None, 3.57)
# (973, 'Japan', 2017, 7646.6367813, None, None, 5.95)
# (974, 'Norway', 2017, 800.8572992, None, None, 5.63)
# (975, 'Russian Federation', 2017, 5467.7826822, None, None, 7.84)
# (976, 'Switzerland', 2017, 2903.6180834, None, None, 0.0)
# (977, 'Tunisia', 2017, 546.1558124, None, None, None)
# (978, 'United Kingdom', 2017, 4989.0378993, None, None, None)
# (979, 'United States of America', 2017, 29487.886464, None, None, 4.45)
# (980, 'Austria', 2018, 1429.4068315, None, None, 6.63)
# (981, 'Belgium', 2018, 5742.2534044, None, None, 0.0)
# (982, 'Belgium_Luxembourg', 2018, 0.0, None, None, None)
# (983, 'Bulgaria', 2018, 737.2439834, None, None, 4.58)
# (984, 'Croatia', 2018, 445.5136108, None, None, None)
# (985, 'Cyprus', 2018, 133.1795419, None, None, 5.79)
# (986, 'Czechia', 2018, 1903.1589019, None, None, 7.27)
# (987, 'Denmark', 2018, 867.9505231, None, None, 5.3)
# (988, 'Estonia', 2018, 147.1377814, None, None, None)
# (989, 'Finland', 2018, 1284.8228208, None, None, 4.24)
# (990, 'France', 2018, 7624.0190207, None, None, 3.68)
# (991, 'Germany', 2018, 22147.1814288, None, None, 5.49)
# (992, 'Greece', 2018, 1160.0236583, None, None, None)
# (993, 'Hungary', 2018, 779.2133677, None, None, 4.83)
# (994, 'Ireland', 2018, 439.6141118, None, None, None)
# (995, 'Italy', 2018, 10639.3546185, None, None, 8.12)
# (996, 'Latvia', 2018, 242.7429785, None, None, 6.6)
# (997, 'Lithuania', 2018, 441.4662257, None, None, 6.4)
# (998, 'Luxembourg', 2018, 433.3236938, None, None, 0.0)
# (999, 'Malta', 2018, 19.3776287, None, None, 15.15)
# (1000, 'Netherlands', 2018, 5520.4375542, None, None, 4.68)
# (1001, 'Poland', 2018, 4325.0623313, None, None, 3.75)
# (1002, 'Portugal', 2018, 1140.202501, None, None, 5.36)
# (1003, 'Romania', 2018, 1174.1428318, None, None, None)
# (1004, 'Slovakia', 2018, 889.5169401, None, None, 6.38)
# (1005, 'Slovenia', 2018, 549.6602152, None, None, 0.0)
# (1006, 'Spain', 2018, 5673.0006739, None, None, 4.1)
# (1007, 'Sweden', 2018, 2262.2141242, None, None, 3.24)
# (1008, 'Japan', 2018, 7539.9818233, None, None, 5.8)
# (1009, 'Norway', 2018, 743.340422, None, None, 5.75)
# (1010, 'Russian Federation', 2018, 5287.5415624, None, None, 7.38)
# (1011, 'Switzerland', 2018, 3086.0189131, None, None, 0.0)
# (1012, 'Tunisia', 2018, 532.966563, None, None, None)
# (1013, 'United Kingdom', 2018, 5687.8597414, None, None, None)
# (1014, 'United States of America', 2018, 28918.207055, None, None, 4.3)
# (1015, 'Austria', 2019, 1447.5136643, None, None, 6.16607)
# (1016, 'Belgium', 2019, 6198.896527, None, None, 0.0)
# (1017, 'Belgium_Luxembourg', 2019, 0.0, None, None, None)
# (1018, 'Bulgaria', 2019, 784.8967153, None, None, 4.208544)
# (1019, 'Croatia', 2019, 466.4175265, None, None, None)
# (1020, 'Cyprus', 2019, 133.2248737, None, None, 5.393971)
# (1021, 'Czechia', 2019, 1608.9214704, None, None, 6.697826)
# (1022, 'Denmark', 2019, 907.935154, None, None, 4.853482)
# (1023, 'Estonia', 2019, 147.848908, None, None, None)
# (1024, 'Finland', 2019, 1515.473931, None, None, 4.004646)
# (1025, 'France', 2019, 7992.9050358, None, None, 3.474105)
# (1026, 'Germany', 2019, 22431.9054319, None, None, 0.0)
# (1027, 'Greece', 2019, 1246.2741298, None, None, None)
# (1028, 'Hungary', 2019, 772.9696635, None, None, 4.348879)
# (1029, 'Ireland', 2019, 438.2803679, None, None, None)
# (1030, 'Italy', 2019, 10913.7572243, None, None, 7.313802)
# (1031, 'Latvia', 2019, 234.9406901, None, None, 5.895347)
# (1032, 'Lithuania', 2019, 473.6308935, None, None, 5.863621)
# (1033, 'Luxembourg', 2019, 402.2667298, None, None, 0.0)
# (1034, 'Malta', 2019, 23.3711797, None, None, 14.267751)
# (1035, 'Netherlands', 2019, 5354.0230034, None, None, 0.0)
# (1036, 'Poland', 2019, 4452.456931, None, None, 3.573126)
# (1037, 'Portugal', 2019, 1219.7647634, None, None, 5.075232)
# (1038, 'Romania', 2019, 1165.0612778, None, None, None)
# (1039, 'Slovakia', 2019, 773.4997431, None, None, 6.10667)
# (1040, 'Slovenia', 2019, 619.5004358, None, None, 0.0)
# (1041, 'Spain', 2019, 5983.5108496, None, None, 3.626647)
# (1042, 'Sweden', 2019, 2347.7968201, None, None, 3.052021)
# (1043, 'Japan', 2019, 8039.6779934, None, None, 5.711998)
# (1044, 'Norway', 2019, 785.890388, None, None, 5.281727)
# (1045, 'Russian Federation', 2019, 5916.632578, None, None, 7.116236)
# (1046, 'Switzerland', 2019, 3228.3829791, None, None, 0.0)
# (1047, 'Tunisia', 2019, 508.332, None, None, None)
# (1048, 'United Kingdom', 2019, 5554.3638794, None, None, None)
# (1049, 'United States of America', 2019, 30854.0726487, None, None, 4.141333)

# %% [markdown]
# ### Reflect and Query

# %%
# # Reflect Database into ORM class
# Base = automap_base()
# # reflect the tables
# Base.prepare(autoload_with=engine)
# Base.classes.keys()

# %%
# Coffee = Base.classes.coffee

# %%
# # create a session
# session = Session(engine)
